# %% [markdown]
# # gym-mtsim: OpenAI Gym - MetaTrader 5 Simulator
#
# `MtSim` is a simulator for the [MetaTrader 5](https://www.metatrader5.com) trading platform alongside an [OpenAI Gym](https://github.com/openai/gym) environment for reinforcement learning-based trading algorithms. `MetaTrader 5` is a **multi-asset** platform that allows trading **Forex**, **Stocks**, **Crypto**, and Futures. It is one of the most popular trading platforms and supports numerous useful features, such as opening demo accounts on various brokers.
#
# The simulator is separated from the Gym environment and can work independently. Although the Gym environment is designed to be suitable for RL frameworks, it is also proper for backtesting and classic analysis.
#
# The goal of this project was to provide a *general-purpose*, *flexible*, and *easy-to-use* library with a focus on *code readability* that enables users to do all parts of the trading process through it from 0 to 100. So, `gym-mtsim` is not just a testing tool or a Gym environment. It is a combination of a **real-world** simulator, a **backtesting** tool with *high detail visualization*, and a **Gym environment** appropriate for RL/classic algorithms.
#
# **Note:** For beginners, it is recommended to check out the [gym-anytrading](https://github.com/AminHP/gym-anytrading) project.

# %% [markdown]
# ## Prerequisites
#
# ### Install MetaTrader 5
# Download and install MetaTrader 5 software from [here](https://www.metatrader5.com/en/download).
#
# Open a demo account on any broker. By default, the software opens a demo account automatically after installation.
#
# Explore the software and try to get familiar with it by trading different symbols in both **hedged** and **unhedged** accounts.
#
# ### Install gym-mtsim
#
# #### Via PIP
# ```bash
# pip install gym-mtsim
# ```
#
# #### From Repository
# ```bash
# git clone https://github.com/AminHP/gym-mtsim
# cd gym-mtsim
# pip install -e .
#
# ## or
#
# pip install --upgrade --no-deps --force-reinstall https://github.com/AminHP/gym-mtsim/archive/main.zip
# ```
#
# ### Install stable-baselines3
# This package is required to run some examples. Install it from [here](https://github.com/DLR-RM/stable-baselines3#installation).

# %% [markdown]
# ## Components

# %% [markdown]
# ### 1. SymbolInfo
#
# This is a data class that contains the essential properties of a symbol. Try to get fully acquainted with [these properties](https://github.com/AminHP/gym-mtsim/blob/main/gym_mtsim/metatrader/symbol.py) in case they are unfamiliar. There are plenty of resources that provide good explanations.

# %% [markdown]
# ### 2. Order
#
# This is another data class that consists of information of an order. Each order has the following properties:
#
# > `id`: A unique number that helps with tracking orders.
# >
# > `type`: An enum that specifies the type of the order. It can be either **Buy** or **Sell**.
# >
# > `symbol`: The symbol selected for the order.
# >
# > `volume`: The volume chose for the order. It can be a multiple of *volume_step* between *volume_min* and *volume_max*.
# >
# > `fee`: It is a tricky property. In MetaTrader, there is *no* such concept called fee. Each symbol has bid and ask prices, the difference between which represents the **fee**. Although MetaTrader API provides these bid/ask prices for the recent past, it is not possible to access them for the distant past. Therefore, the **fee** property helps to manage the mentioned difference.
# >
# > `entry_time`: The time when the order was placed.
# >
# > `entry_price`: The **close** price when the order was placed.
# >
# > `exit_time`: The time when the order was closed.
# >
# > `exit_price`: The **close** price when the order was closed.
# >
# > `profit`: The amount of profit earned by this order so far.
# >
# > `margin`: The required amount of margin for this order.
# >
# > `closed`: A boolean that specifies whether this order is closed or not.

# %% [markdown]
# ### 3. MtSimulator
#
# This is the core class that simulates the main parts of MetaTrader. Most of its public properties and methods are explained here. But feel free to take a look at the complete [source code](https://github.com/AminHP/gym-mtsim/blob/main/gym_mtsim/simulator/mt_simulator.py).
#
# * Properties:
#
#     > `unit`: The unit currency. It is usually *USD*, but it can be anything the broker allows, such as *EUR*.
#     >
#     > `balance`: The amount of money before taking into account any open positions.
#     >
#     > `equity`: The amount of money, including the value of any open positions.
#     >
#     > `margin`: The amount of money which is required for having positions opened.
#     >
#     > `leverage`: The leverage ratio.
#     >
#     > `free_margin`: The amount of money that is available to open new positions.
#     >
#     > `margin_level`: The ratio between **equity** and **margin**.
#     >
#     > `stop_out_level`: If the **margin_level** drops below **stop_out_level**, the most unprofitable position will be closed automatically by the broker.
#     >
#     > `hedge`: A boolean that specifies whether hedging is enabled or not.
#     >
#     > `symbols_info`: A dictionary that contains symbols' information.
#     >
#     > `symbols_data`: A dictionary that contains symbols' OHLCV data.
#     >
#     > `orders`: The list of open orders.
#     >
#     > `closed_orders`: The list of closed orders.
#     >
#     > `current_time`: The current time of the system.
#
# * Methods:
#
#     > `download_data`: Downloads required data from MetaTrader for a list of symbols in a time range. This method can be overridden in order to download data from servers other than MetaTrader. *Note that this method only works on Windows, as the MetaTrader5 Python package is not available on other platforms.*
#     >
#     > `save_symbols`: Saves the downloaded symbols' data to a file.
#     >
#     > `load_symbols`: Loads the symbols' data from a file.
#     >
#     > `tick`: Moves forward in time (by a delta time) and updates orders and other related properties.
#     >
#     > `create_order`: Creates a **Buy** or **Sell** order and updates related properties.
#     >
#     > `close_order`: Closes an order and updates related properties.
#     >
#     > `get_state`: Returns the state of the system. The result is similar to the *Trading tab* and *History tab* of the *Toolbox window* in MetaTrader software.

# %% [markdown]
# ### 4. MtEnv
#
# This is the Gym environment that works on top of the *MtSim*. Most of its public properties and methods are explained here. But feel free to take a look at the complete [source code](https://github.com/AminHP/gym-mtsim/blob/main/gym_mtsim/envs/mt_env.py).
#
# * Properties:
#
#     > `original_simulator`: An instance of **MtSim** class as a baseline for simulating the system.
#     >
#     > `simulator`: The current simulator in use. It is a copy of the **original_simulator**.
#     >
#     > `trading_symbols`: The list of symbols to trade.
#     >
#     > `time_points`: A list of time points based on which the simulator moves time. The default value is taken from the *pandas DataFrame.Index* of the first symbol in the **trading_symbols** list.
#     >
#     > `hold_threshold`: A probability threshold that controls holding or placing a new order.
#     >
#     > `close_threshold`: A probability threshold that controls closing an order.
#     >
#     > `fee`: A constant number or a callable that takes a *symbol* as input and returns the **fee** based on that.
#     >
#     > `symbol_max_orders`: Specifies the maximum number of open positions per symbol in hedge trading.
#     >
#     > `multiprocessing_processes`: Specifies the maximum number of processes used for parallel processing.
#     >
#     > `prices`: The symbol prices over time. It is used to calculate signal features and render the environment.
#     >
#     > `signal_features`: The extracted features over time. It is used to generate *Gym observations*.
#     >
#     > `window_size`: The number of time points (current and previous points) as the length of each observation's features.
#     >
#     > `features_shape`: The shape of a single observation's features.
#     >
#     > `action_space`: The *Gym action_space* property. It has a complex structure since **stable-baselines** does not support *Dict* or *2D Box* action spaces. The action space is a 1D vector of size `count(trading_symbols) * (symbol_max_orders + 2)`. For each symbol, two types of actions can be performed, closing previous orders and placing a new order. The former is controlled by the first *symbol_max_orders* elements and the latter is controlled by the last two elements. Therefore, the action for each symbol is ***[probability of closing order 1, probability of closing order 2, ..., probability of closing order symbol_max_orders, probability of holding or creating a new order, volume of the new order]***. The last two elements specify whether to hold or place a new order and the volume of the new order (positive volume indicates buy and negative volume indicates sell). These elements are a number in range (-∞, ∞), but the probability values must be in the range [0, 1]. This is a problem with **stable-baselines** as mentioned earlier. To overcome this problem, it is assumed that the probability values belong to the [logit](https://en.wikipedia.org/wiki/Logit) function. So, applying the [expit](https://en.wikipedia.org/wiki/Expit) function on them gives the desired probability values in the range [0, 1]. This function is applied in the **step** method of the environment.
#     >
#     > `observation_space`: The *Gym observation_space* property. Each observation contains information about *balance*, *equity*, *margin*, *features*, and *orders*. The **features** is a window on the *signal_features* from index *current_tick - window_size + 1* to *current_tick*. The **orders** is a 3D array. Its first dimension specifies the symbol index in the *trading_symbols* list. The second dimension specifies the order number (each symbol can have more than one open order at the same time in hedge trading). The last dimension has three elements, *entry_price*, *volume*, and *profit* of corresponding order.
#     >
#     > `history`: Stores the information of all steps.
#
# * Methods:
#
#     > `seed`: The typical *Gym seed* method.
#     >
#     > `reset`: The typical *Gym reset* method.
#     >
#     > `step`: The typical *Gym step* method.
#     >
#     > `render`: The typical *Gym render* method. It can render in three modes, **human**, **simple_figure**, and **advanced_figure**.
#     >
#     > `close`: The typical *Gym close* method.
#
# * Virtual Methods:
#
#     > `_get_prices`: It is called in the constructor and calculates symbol **prices**.
#     >
#     > `_process_data`: It is called in the constructor and calculates **signal_features**.
#     >
#     > `_calculate_reward`: The reward function for the RL agent.

# %% [markdown]
# ## A Simple Example

# %% [markdown]
# ### MtSim

# %% [markdown]
# #### Create a simulator with custom parameters

# %%
import pytz
from datetime import datetime, timedelta
from gym_mtsim import MtSimulator, OrderType, Timeframe, FOREX_DATA_PATH


sim = MtSimulator(
    unit='USD',
    balance=10000.,
    leverage=100.,
    stop_out_level=0.2,
    hedge=False,
)

if not sim.load_symbols(FOREX_DATA_PATH):
    sim.download_data(
        symbols=['EURUSD', 'GBPCAD', 'GBPUSD', 'USDCAD', 'USDCHF', 'GBPJPY', 'USDJPY'],
        time_range=(
            datetime(2021, 5, 5, tzinfo=pytz.UTC),
            datetime(2024, 4, 1, tzinfo=pytz.UTC)
        ),
        timeframe=Timeframe.M15
    )
    sim.save_symbols(FOREX_DATA_PATH)

# %% [markdown]
# #### Place some orders

# %%
sim.current_time = datetime(2021, 8, 30, 0, 17, 52, tzinfo=pytz.UTC)

order1 = sim.create_order(
    order_type=OrderType.Buy,
    symbol='GBPCAD',
    volume=1.,
    fee=0.0003,
)

sim.tick(timedelta(days=2))

order2 = sim.create_order(
    order_type=OrderType.Sell,
    symbol='USDJPY',
    volume=2.,
    fee=0.01,
)

sim.tick(timedelta(days=5))

state = sim.get_state()

print(
    f"balance: {state['balance']}, equity: {state['equity']}, margin: {state['margin']}\n"
    f"free_margin: {state['free_margin']}, margin_level: {state['margin_level']}\n"
)
state['orders']
# Out:
# balance: 10000.0, equity: 10717.58118589908, margin: 3375.480933228619
# free_margin: 7342.1002526704615, margin_level: 3.1751271592500743
#    Id  Symbol  Type  Volume                Entry Time  Entry Price  \
# 0   2  USDJPY  Sell     2.0 2021-09-01 00:17:52+00:00    110.02500
# 1   1  GBPCAD   Buy     1.0 2021-08-30 00:17:52+00:00      1.73389
#
#                   Exit Time  Exit Price  Exit Balance  Exit Equity  \
# 0 2021-09-06 00:17:52+00:00   109.71200           NaN          NaN
# 1 2021-09-06 00:17:52+00:00     1.73626           NaN          NaN
#
#        Profit       Margin     Fee  Closed
# 0  552.355257  2000.000000  0.0100   False
# 1  165.225928  1375.480933  0.0003   False

# %% [markdown]
# #### Close all orders

# %%
order1_profit = sim.close_order(order1)
order2_profit = sim.close_order(order2)

# alternatively:
# for order in sim.orders:
#     sim.close_order(order)

state = sim.get_state()

print(
    f"balance: {state['balance']}, equity: {state['equity']}, margin: {state['margin']}\n"
    f"free_margin: {state['free_margin']}, margin_level: {state['margin_level']}\n"
)
state['orders']
# Out:
# balance: 10717.58118589908, equity: 10717.58118589908, margin: 0.0
# free_margin: 10717.58118589908, margin_level: inf
#    Id  Symbol  Type  Volume                Entry Time  Entry Price  \
# 0   2  USDJPY  Sell     2.0 2021-09-01 00:17:52+00:00    110.02500
# 1   1  GBPCAD   Buy     1.0 2021-08-30 00:17:52+00:00      1.73389
#
#                   Exit Time  Exit Price  Exit Balance   Exit Equity  \
# 0 2021-09-06 00:17:52+00:00   109.71200  10717.581186  10717.581186
# 1 2021-09-06 00:17:52+00:00     1.73626  10165.225928  10717.581186
#
#        Profit       Margin     Fee  Closed
# 0  552.355257  2000.000000  0.0100    True
# 1  165.225928  1375.480933  0.0003    True

# %% [markdown]
# ### MtEnv

# %% [markdown]
# #### Create an environment

# %%
import gymnasium as gym
import gym_mtsim

env = gym.make('forex-hedge-v0')
# env = gym.make('stocks-hedge-v0')
# env = gym.make('crypto-hedge-v0')
# env = gym.make('mixed-hedge-v0')

# env = gym.make('forex-unhedge-v0')
# env = gym.make('stocks-unhedge-v0')
# env = gym.make('crypto-unhedge-v0')
# env = gym.make('mixed-unhedge-v0')

# %% [markdown]
# * This will create a default environment. There are eight default environments, but it is also possible to create environments with custom parameters.

# %% [markdown]
# #### Create an environment with custom parameters

# %%
import sys
import datetime as dt
import pytz
sys.path.append("C:/Users/WilliamFetzner/Documents/Trading/")
from gym_mtsim_forked.gym_mtsim.data import STOCKS_DATA_PATH
from gym_mtsim import OrderType, Timeframe, MtEnv, MtSimulator
sim = MtSimulator(
    unit='USD',
    balance=10000.,
    leverage=100.,
    stop_out_level=0.2,
    hedge=False,
)
# Out:
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment forex-hedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment forex-unhedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment stocks-hedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment stocks-unhedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment crypto-hedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment crypto-unhedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment mixed-hedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# c:\Users\WilliamFetzner\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment mixed-unhedge-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
current_time = dt.datetime.now() + dt.timedelta(hours=7)
current_time
# Out:
# datetime.datetime(2024, 4, 28, 14, 5, 51, 474841)

# %%
sim.download_data(
    symbols=['EURUSD', 'AUDCHF', 'NZDCHF', 'GBPNZD', 'USDCAD'],
    time_range=(
        dt.datetime(2024, 1, 1, tzinfo=pytz.UTC),
        current_time
    ),
    timeframe=Timeframe.H1
)
sim.save_symbols(STOCKS_DATA_PATH)

# %%
import pickle
# unpack the pickle file and load the data that is in symbols_forex.pkl
with open(STOCKS_DATA_PATH, 'rb') as f:
    symbols = pickle.load(f)
df = symbols[1]['EURUSD']

# %%
df
# Out:
#                               Open    Close      Low     High  Volume
# Time
# 2024-01-02 00:00:00+00:00  1.10437  1.10439  1.10411  1.10451     375
# 2024-01-02 01:00:00+00:00  1.10441  1.10364  1.10354  1.10447    2207
# 2024-01-02 02:00:00+00:00  1.10364  1.10381  1.10340  1.10384    2376
# 2024-01-02 03:00:00+00:00  1.10380  1.10347  1.10340  1.10432    5079
# 2024-01-02 04:00:00+00:00  1.10348  1.10187  1.10180  1.10358    5520
# ...                            ...      ...      ...      ...     ...
# 2024-04-26 19:00:00+00:00  1.06856  1.06945  1.06838  1.06963    1378
# 2024-04-26 20:00:00+00:00  1.06945  1.06941  1.06931  1.06979     884
# 2024-04-26 21:00:00+00:00  1.06941  1.07054  1.06936  1.07057     883
# 2024-04-26 22:00:00+00:00  1.07054  1.06998  1.06967  1.07070     846
# 2024-04-26 23:00:00+00:00  1.06994  1.06922  1.06904  1.07012     792
#
# [2013 rows x 5 columns]

# %%
df[df['Open'] == 1.10420]
# df[df['Open'] == 1.10364]
# Out:
# Empty DataFrame
# Columns: [Open, Close, Low, High, Volume]
# Index: []

# %%
import pytz
from datetime import datetime, timedelta
import numpy as np
from gym_mtsim import MtEnv, MtSimulator


sim = MtSimulator(
    unit='USD',
    balance=10000.,
    leverage=100.,
    stop_out_level=0.2,
    hedge=True,
    symbols_filename='C:/Users/WilliamFetzner/Documents/Trading/gym_mtsim_forked/gym_mtsim/data/symbols_forex_1_1_24_4_11_24.pkl'
)

env = MtEnv(
    original_simulator=sim,
    trading_symbols=['EURUSD'],
    window_size=10,
    # time_points=[desired time points ...],
    hold_threshold=0.5,
    close_threshold=0.5,
    fee=lambda symbol: {
        # 'USDCAD': max(0., np.random.normal(0.0007, 0.00005)),
        'EURUSD': max(0., np.random.normal(0.0002, 0.00003)),
        # 'USDJPY': max(0., np.random.normal(0.02, 0.003)),
    }[symbol],
    symbol_max_orders=2,
    multiprocessing_processes=2
)

# %%
env.time_points
# Out:
# [datetime.datetime(2024, 1, 2, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 2, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 3, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 4, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 5, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 8, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 9, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 10, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 11, 4, 15, tzinfo=datetime.timezone.utc),
# ...
#  datetime.datetime(2024, 1, 12, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 12, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 9, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 10, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 10, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 11, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 11, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 11, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 11, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 12, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 12, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 12, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 12, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 13, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 13, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 13, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 13, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 14, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 14, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 14, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 14, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 15, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 15, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 15, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 15, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 16, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 16, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 16, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 16, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 17, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 17, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 17, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 17, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 18, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 18, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 18, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 18, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 19, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 19, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 19, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 19, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 20, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 20, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 20, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 20, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 21, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 21, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 21, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 21, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 22, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 22, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 22, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 22, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 23, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 23, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 23, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 15, 23, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 0, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 0, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 1, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 1, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 1, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 2, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 2, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 2, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 3, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 3, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 3, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 4, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 4, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 4, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 5, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 5, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 5, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 6, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 6, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 6, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 7, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 7, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 7, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 7, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 8, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 8, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 8, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 8, 45, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 9, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 9, 15, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 9, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2024, 1, 16, 9, 45, tzinfo=datetime.timezone.utc),
#  ...]

# %%
df['Close']
# Out:
# Time
# 2024-01-02 00:00:00+00:00    1.10449
# 2024-01-02 00:15:00+00:00    1.10426
# 2024-01-02 00:30:00+00:00    1.10428
# 2024-01-02 00:45:00+00:00    1.10439
# 2024-01-02 01:00:00+00:00    1.10382
#                               ...
# 2024-04-10 23:00:00+00:00    1.07438
# 2024-04-10 23:15:00+00:00    1.07445
# 2024-04-10 23:30:00+00:00    1.07414
# 2024-04-10 23:45:00+00:00    1.07416
# 2024-04-11 00:00:00+00:00    1.07427
# Name: Close, Length: 6900, dtype: float64

# %%
obs, _ = env.reset()
obs
# Out:
# {'balance': array([10000.]),
#  'equity': array([10000.]),
#  'margin': array([0.]),
#  'features': array([[1.10449, 1.10437],
#         [1.10426, 1.1042 ],
#         [1.10428, 1.10437],
#         [1.10439, 1.10423],
#         [1.10382, 1.10441],
#         [1.10377, 1.10383],
#         [1.10366, 1.10377],
#         [1.10364, 1.10366],
#         [1.1037 , 1.10364],
#         [1.10347, 1.1037 ]]),
#  'orders': array([[[0., 0., 0.],
#          [0., 0., 0.]]])}

# %% [markdown]
# #### Print some information

# %%
print("env information:")

for symbol in env.prices:
    print(f"> prices[{symbol}].shape:", env.prices[symbol].shape)

print("> signal_features.shape:", env.signal_features.shape)
print("> features_shape:", env.features_shape)
# Out:
# env information:
# > prices[GBPCAD].shape: (72272, 2)
# > prices[EURUSD].shape: (72272, 2)
# > prices[USDJPY].shape: (72272, 2)
# > signal_features.shape: (72272, 6)
# > features_shape: (10, 6)

# %% [markdown]
# #### Trade randomly

# %%
observation = env.reset()

while True:
    action = env.action_space.sample()
    observation, reward, terminated, truncated, info = env.step(action)
    print(observation['orders'])
    done = terminated or truncated

    if done:
        # print(info)
        print(
            f"balance: {info['balance']}, equity: {info['equity']}, margin: {info['margin']}\n"
            f"free_margin: {info['free_margin']}, margin_level: {info['margin_level']}\n"
            f"step_reward: {info['step_reward']}"
        )
        break

# %%
observation
# Out:
# {'balance': array([3217.98448467]),
#  'equity': array([3217.98448467]),
#  'margin': array([0.]),
#  'features': array([[1.07362, 1.0744 ],
#         [1.074  , 1.07364],
#         [1.07428, 1.074  ],
#         [1.0745 , 1.07428],
#         [1.07438, 1.07449],
#         [1.07438, 1.07436],
#         [1.07445, 1.07438],
#         [1.07414, 1.07445],
#         [1.07416, 1.07414],
#         [1.07427, 1.07415]]),
#  'orders': array([[[0., 0., 0.],
#          [0., 0., 0.]]])}

# %% [markdown]
# #### Render in *human* mode

# %%
state = env.render()

print(
    f"balance: {state['balance']}, equity: {state['equity']}, margin: {state['margin']}\n"
    f"free_margin: {state['free_margin']}, margin_level: {state['margin_level']}\n"
)
state['orders']
# Out:
# balance: 62.67749753898616, equity: 62.67749753898616, margin: 4.547473508864641e-13
# free_margin: 62.677497538985705, margin_level: inf
#       Id  Symbol  Type  Volume                Entry Time  Entry Price  \
# 0    337  EURUSD  Sell    0.04 2024-04-10 11:45:00+00:00      1.08604
# 1    336  USDJPY   Buy    0.02 2024-04-03 21:30:00+00:00    151.66600
# 2    335  GBPCAD   Buy    0.01 2024-03-29 20:00:00+00:00      1.70880
# 3    334  EURUSD   Buy    0.04 2024-03-07 23:30:00+00:00      1.09460
# 4    333  USDJPY   Buy    0.01 2024-02-15 12:45:00+00:00    150.04600
# ..   ...     ...   ...     ...                       ...          ...
# 332    5  USDJPY   Buy    3.24 2020-03-31 13:15:00+00:00    108.52000
# 333    4  EURUSD  Sell    8.10 2020-03-31 11:45:00+00:00      1.09787
# 334    3  GBPCAD  Sell    1.79 2020-03-31 09:15:00+00:00      1.74807
# 335    2  EURUSD   Buy    3.72 2020-03-31 03:00:00+00:00      1.10316
# 336    1  EURUSD  Sell    6.82 2020-03-31 02:30:00+00:00      1.10260
#
#                     Exit Time  Exit Price  Exit Balance   Exit Equity  \
# 0   2024-04-10 13:30:00+00:00     1.08634     62.677498     62.677498
# 1   2024-04-03 22:00:00+00:00   151.67600     64.584394     64.584394
# 2   2024-03-29 20:30:00+00:00     1.70882     64.726528     64.726528
# 3   2024-03-08 00:00:00+00:00     1.09448     65.196971     65.196971
# 4   2024-02-15 13:00:00+00:00   150.02000     66.510626     66.510626
# ..                        ...         ...           ...           ...
# 332 2020-03-31 13:30:00+00:00   108.53600  10065.033062  10065.033062
# 333 2020-03-31 12:30:00+00:00     1.09686  10072.150012  10072.150012
# 334 2020-03-31 09:30:00+00:00     1.74696   9437.748907   9437.748907
# 335 2020-03-31 03:30:00+00:00     1.10316   9379.250843   9379.250843
# 336 2020-03-31 03:00:00+00:00     1.10316   9449.023376   9449.023376
#
#          Profit       Margin       Fee  Closed
# 0     -1.906896    43.441600  0.000177    True
# 1     -0.142134    20.000000  0.020779    True
# 2     -0.470443    12.616191  0.000657    True
# 3     -1.313656    43.784000  0.000208    True
# 4     -0.290010    10.000000  0.017507    True
# ..          ...          ...       ...     ...
# 332   -7.116950  3240.000000  0.018384    True
# 333  634.401105  8892.747000  0.000227    True
# 334   58.498064  2289.137763  0.000663    True
# 335  -69.772533  4103.755200  0.000188    True
# 336 -550.976624  7519.732000  0.000248    True
#
# [337 rows x 14 columns]

# %% [markdown]
# #### Render in *simple_figure* mode
#
# * Each *symbol* is illustrated with a separate color.
# * The **green**/**red** triangles show successful **buy**/**sell** actions.
# * The **gray** triangles indicate that the **buy**/**sell** action has encountered an **error**.
# * The **black** vertical bars specify **close** actions.

# %%
env.render('simple_figure')

# %% [markdown]
# #### Render in *advanced_figure* mode
#
# * Clicking on a symbol name will hide/show its plot.
# * Hovering over points and markers will display their detail.
# * The size of triangles indicates their relative volume.

# %%
env.render('advanced_figure', time_format="%Y-%m-%d")

# %% [markdown]
# ### A Complete Example using `stable-baselines`

# %%
import gymnasium as gym
from gym_mtsim import (
    Timeframe, SymbolInfo,
    MtSimulator, OrderType, Order, SymbolNotFound, OrderNotFound,
    MtEnv,
    FOREX_DATA_PATH, STOCKS_DATA_PATH, CRYPTO_DATA_PATH, MIXED_DATA_PATH,
)
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import DummyVecEnv
import random
import numpy as np
import torch

env_name = 'forex-hedge-v0'

# reproduce training and test
seed = 2024
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

env = gym.make(env_name)
model = A2C('MultiInputPolicy', env, verbose=0)
model.learn(total_timesteps=1000)

observation, info = env.reset(seed=seed)

while True:
    action, _states = model.predict(observation)
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    if done:
        break

env.unwrapped.render('advanced_figure', time_format='%Y-%m-%d')

# %% [markdown]
# ## References
#
# * [https://www.mql5.com/en/docs/python_metatrader5](https://www.mql5.com/en/docs/python_metatrader5)
# * [https://www.metatrader5.com/en/terminal/help/trading_advanced/margin_forex](https://www.metatrader5.com/en/terminal/help/trading_advanced/margin_forex)
# * [https://admiralmarkets.com/education/articles/forex-basics/margin-in-forex-trading-margin-level-vs-margin-call](https://admiralmarkets.com/education/articles/forex-basics/margin-in-forex-trading-margin-level-vs-margin-call)
# * [https://www.investopedia.com/articles/forex/12/calculating-profits-and-losses-of-forex-trades.asp](https://www.investopedia.com/articles/forex/12/calculating-profits-and-losses-of-forex-trades.asp)
